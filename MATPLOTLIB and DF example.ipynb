# %% [markdown]
# # Tutorial on using MATPLOTLIB with DATAFRAMES (PANDAS)
# # http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %%
from IPython.display import Image
Image("header.png")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

# %%
df.plot(kind='scatter',x='num_children',y='num_pets',color='red')
plt.show()

# %% [markdown]
# # Tutorial dealing with rows and columns
# # https://www.geeksforgeeks.org/dealing-with-rows-and-columns-in-pandas-dataframe/

# %%
#retrive the row
# first list them all and then select
list(df.index.values)
#first = df.loc["name"]
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list(df)
# Out:
# ['age', 'gender', 'name', 'num_children', 'num_pets', 'state']

# %%
# bar works but not scatter because name is a string
df.plot(kind='bar',x='name',y='age')

# %% [markdown]
# # Tutorial #3
# # Example of line or scatter plot
# # https://pandas.pydata.org/pandas-docs/version/0.23.1/generated/pandas.DataFrame.plot.line.html

# %%
df2 = pd.DataFrame({
...    'pig': [20, 18, 489, 675, 1776],
...    'horse': [4, 25, 281, 600, 1900]
...    }, index=[1990, 1997, 2003, 2009, 2014])

# %%
#lines = df2.plot.line()
axes = df2.plot.line(subplots=True)

# %%
plt.show()

# %% [markdown]
# # Tutorial 4
# # Outputing python output to file
# # https://stackoverflow.com/questions/7152762/how-to-redirect-print-output-to-a-file-using-python

# %%
filename = 'test.txt'
f = open(filename,'w')
#does not work
#print >>f, 'whatever'     # Python 2.x
#print('whatever', file=f) # Python 3.x
#works
#f.write('whatever')

# %%
# FAILS
temp = df.index.values
f.write(temp)
